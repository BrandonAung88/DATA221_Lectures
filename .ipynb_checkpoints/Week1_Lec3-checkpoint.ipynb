# %%
a = 1 #int
b = 4.35 #float

print(a) 
print(b)
# Out:
# 1
# 4.35

# %%
my_name = "Brandon"
print(my_name)
# Out:
# Brandon

# %%
l = len(s)
print(l)
# Out:
# 7

# %%
f = True
print(f)
# Out:
# True

# %%
t = None
print(t)
# Out:
# None

# %%
l = [1,4.35, "begin"]

print(l[0])
print(l[0:2])

l.append(5)
print(l)

l.extend([6,["yes",7]])
print(l)

print(len(l))
# Out:
# 1
# [1, 4.35]
# [1, 4.35, 'begin', 5]
# [1, 4.35, 'begin', 5, 6, ['yes', 7]]
# 6

# %%
x, y = l[0:2]
print(x)
print(y)
# Out:
# 1
# 4.35

# %%
print("end" in l)
# Out:
# False

# %%
print("t" in "start")
# Out:
# True

# %%
dict_1 = {"Day":1, "Month":"Jan", "Year": 2003}

dict_1["Year"] = 2008
dict_1["Name"] = 'Brandon'


print(dict_1)
# Out:
# {'Day': 1, 'Month': 'Jan', 'Year': 2008, 'Name': 'Brandon'}

# %%
dict_components = {"quizzes" : 20, "A1": 5, "A2": 5, 
                   "Midterm": 20, "A3": 5, "A4": 5, 
                   "Project Proposal": 10, "Project Final Report": 15,
                   "Project Presentations" : 25}

# %%
# Out:
# B

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 studentNaame
#
# NameError: name 'studentNaame' is not defined
