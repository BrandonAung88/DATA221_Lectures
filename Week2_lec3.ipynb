# %%
import numpy as np

np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from numpy import array

array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from numpy import *

array([1,2,3])
# Out:
# array([1, 2, 3])
